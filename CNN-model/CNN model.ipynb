# %%
import os
import pandas as pd
import json
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense
from tensorflow.keras.optimizers import Adam

# %%
# File path to JSON dataset
file_path = r'C:\Users\Administrator\Documents\GitHub\Datasets\yelp_academic_dataset_review.json'

# Load data in chunks
chunk_size = 1000000
model_save_path = 'sentiment_analysis_cnn_model.h5'

# Initialize the model outside the loop
model = None
epochs = 10

# %%
for chunk in pd.read_json(file_path, lines=True, chunksize=chunk_size):
    print(chunk)
    # Accessing the data DataFrame
    texts = chunk['text'].tolist()
    labels = chunk['stars'].tolist()

    # Tokenize the text
    tokenizer = Tokenizer(num_words=10000, oov_token='<OOV>')
    tokenizer.fit_on_texts(texts)
    sequences = tokenizer.texts_to_sequences(texts)

    # Padding sequences
    max_len = 100 
    padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post', truncating='post')

    # Convert labels to numerical format
    numeric_labels = np.array(labels)

    # Split the dataset into training and testing sets
    x_train, x_test, y_train, y_test = train_test_split(padded_sequences, numeric_labels, test_size=0.2, random_state=42)

    # Build or load the CNN model
    if model is None or not os.path.exists(model_save_path):
        embedding_dim = 50
        filters = 64
        kernel_size = 3

        model = Sequential()
        model.add(Embedding(input_dim=10000, output_dim=embedding_dim, input_length=max_len))
        model.add(Conv1D(filters=filters, kernel_size=kernel_size, activation='relu'))
        model.add(GlobalMaxPooling1D())
        model.add(Dense(1, activation='linear'))  # Used linear activation for regression
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')  # Use mean squared error for regression
    else:
        # Load the previously trained model
        model = load_model(model_save_path)

    # Train the model
    model.fit(x_train, y_train, epochs=epochs, batch_size=128, validation_split=0.1)
# Out:
#                      review_id                 user_id  \
# 0       KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1       BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2       saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3       AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4       Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                        ...                     ...
# 999995  t-2o35kr7Q9DSaeuKhaDuQ  oX7o1TH0PHUWp9r9ry9_vw
# 999996  fLIwWCvdul9PNWYfJt5QWA  v8wlapFKVLs2qTYCGhCdiw
# 999997  ETAiy6wEM-r9ve4SKDhBpg  rLlYc1RzIBnOmnX3AbpEYw
# 999998  8OgvSXuc6KjAt2fSz9LuzA  eEH-8CEPU5ndPxDGzVfHiQ
# 999999  TQoVzNXqDkiDXgzlw8cyaQ  HYmGwYXvcYmW7dDjuWKJfw
#
#                    business_id  stars  useful  funny  cool  \
# 0       XQfwVwDr-v0ZS3_CbbE5Xw      3       0      0     0
# 1       7ATYjTIgM3jUlt4UM3IypQ      5       1      0     1
# 2       YjUWPpI6HXG530lwP-fb2A      3       0      0     0
# 3       kxX2SOes4o-D3ZQBkiMRfA      5       1      0     1
# 4       e4Vwtrqf-wpJfwesgvdgxQ      4       1      0     1
# ...                        ...    ...     ...    ...   ...
# 999995  jLn69WQupjsDKrbPw_nlGQ      3       0      1     0
# 999996  t6v8g8UeNiq3O2GoEc7R4Q      4       0      0     0
# 999997  ZYRul0i1bhOjirHED6Kd0w      3       0      0     0
# 999998  onGXKwnxPLtKnO8yqQMPSA      1       1      0     1
# 999999  54vEFcAri3Wj6cdM4ljDBA      4       2      1     0
#
#                                                      text                date
# 0       If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1       I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2       Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3       Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4       Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15
# ...                                                   ...                 ...
# 999995  Never really had any issues here other than th... 2017-11-15 09:43:07
# 999996  Fish recently moved a couple of doors down the... 2014-09-03 18:27:33
# 999997  I've been to South House around a dozen or so ... 2016-02-20 22:25:29
# 999998  Wow! I am shocked at these reviews. I have tri... 2010-06-27 02:17:30
# 999999  headed to St. Louis for a little getaway with ... 2012-11-05 03:25:02
#
# [1000000 rows x 9 columns]
# Epoch 1/10
# 5625/5625 [==============================] - 67s 10ms/step - loss: 0.7475 - val_loss: 0.5407
# Epoch 2/10
# 5625/5625 [==============================] - 59s 11ms/step - loss: 0.5058 - val_loss: 0.5256
# Epoch 3/10
# 5625/5625 [==============================] - 50s 9ms/step - loss: 0.4637 - val_loss: 0.5183
# Epoch 4/10
# 5625/5625 [==============================] - 57s 10ms/step - loss: 0.4323 - val_loss: 0.5228
# Epoch 5/10
# 5625/5625 [==============================] - 59s 10ms/step - loss: 0.4067 - val_loss: 0.5370
# Epoch 6/10
# 5625/5625 [==============================] - 57s 10ms/step - loss: 0.3844 - val_loss: 0.5399
# Epoch 7/10
# 5625/5625 [==============================] - 60s 11ms/step - loss: 0.3658 - val_loss: 0.5477
# Epoch 8/10
# 5625/5625 [==============================] - 65s 12ms/step - loss: 0.3491 - val_loss: 0.5579
# Epoch 9/10
# 5625/5625 [==============================] - 58s 10ms/step - loss: 0.3345 - val_loss: 0.5604
# Epoch 10/10
# 5625/5625 [==============================] - 53s 9ms/step - loss: 0.3220 - val_loss: 0.5658
#                       review_id                 user_id  \
# 1000000  1yzkzMBuDc0oIATmm-YT6A  batsML880B8-BMV1YBh0VQ
# 1000001  p1He-R5tvsxamxNF0Bf-cg  T9n6TKhnkqwh7u3a70O-pQ
# 1000002  fOOZEC8D2f1hI6bs08X3gQ  4zUi7exGanxHz_zXJuHjMw
# 1000003  ZoeZ_aC_CiWSuqvfe38nAQ  bHNxtcIKeU5Ifnd4BwBoWw
# 1000004  ygAtxZ1Gaimqj8IZGPobRA  W9zN7u6b-e3bkZ69W92fig
# ...                         ...                     ...
# 1999995  5Kj5gEHBP8SIYeiwaNV9xg  Ux0CsHDQvEbtZXlGDgcCHg
# 1999996  wQq7vGWf8euzUk7TkoVAXw  5jKScvMqxW_rzd0D8xgX1A
# 1999997  eAKeO7EX8kSKsCBcq7mKTA  _Redmmq2oiUvMFhzS-CAVA
# 1999998  HaY4k2iVPhcTOwfGVPlYSg  BnMfYA-c2YQbzVMto2wO5w
# 1999999  MmFruENWfbqghG5hwJhIaw  p465OiphoWkYQDnbK_hLIg
#
#                     business_id  stars  useful  funny  cool  \
# 1000000  NLV0ppsHTiJk6JVdFSxVAQ      5       1      0     0
# 1000001  c_xAbBTeiIHqPm1zMOvQcg      5       0      0     0
# 1000002  Sv1MEZP-mMfp8SmE0hwYEA      5       0      0     0
# 1000003  KBG3GV4WHU-iLLSWiapbJw      4       0      0     0
# 1000004  BX3LLonrLLLfVX-tNrE7yA      5       1      0     0
# ...                         ...    ...     ...    ...   ...
# 1999995  TGiTwNYy3ZvOoHTT7ZHpgg      1       0      0     0
# 1999996  kOmhn5Eo6AWzMVL6ALRq2Q      5       2      0     1
# 1999997  m6ZcOrHJHYmIPhjgh8cycw      2       0      0     0
# 1999998  YCfMNP_1YCTXTKlrnw44vQ      5       0      0     0
# 1999999  YceIYPMBP3oKcuEFhj2_Gg      5       0      0     0
#
#                                                       text                date
# 1000000  Pleasantly intrigued by the combination of bre... 2016-05-29 00:29:56
# 1000001  I am not sure what I was expecting, but this w... 2016-11-19 04:50:47
# 1000002  Mmm....still thinking about it right now. The ... 2015-01-18 06:41:40
# 1000003  Very good even by Nashville and non-Nashville ... 2011-05-10 02:24:14
# 1000004  New location is beautiful! This location is st... 2017-11-28 18:22:51
# ...                                                    ...                 ...
# 1999995  Had to wait over 20 minutes for my order, then... 2020-09-20 00:13:27
# 1999996  Very good food!! My wife and I got crab legs, ... 2020-06-11 23:25:17
# 1999997  Food was just ok, nothing to write home about.... 2020-12-02 23:02:55
# 1999998  Great spot!   Food and service was terrific!  ... 2021-01-09 02:45:57
# 1999999  My ten-year-old Sheltie, Diane, had a severe l... 2020-12-04 22:23:55
#
# [1000000 rows x 9 columns]
# Epoch 1/10
# 5625/5625 [==============================] - 57s 10ms/step - loss: 0.7402 - val_loss: 0.5776
# Epoch 2/10
# 5625/5625 [==============================] - 62s 11ms/step - loss: 0.5133 - val_loss: 0.5298
# Epoch 3/10
# 5625/5625 [==============================] - 59s 10ms/step - loss: 0.4694 - val_loss: 0.5283
# Epoch 4/10
# 5625/5625 [==============================] - 62s 11ms/step - loss: 0.4364 - val_loss: 0.5346
# Epoch 5/10
# 5625/5625 [==============================] - 53s 9ms/step - loss: 0.4093 - val_loss: 0.5419
# Epoch 6/10
# 5625/5625 [==============================] - 33s 6ms/step - loss: 0.3872 - val_loss: 0.5489
# Epoch 7/10
# 5625/5625 [==============================] - 33s 6ms/step - loss: 0.3679 - val_loss: 0.5681
# Epoch 8/10
# 5625/5625 [==============================] - 45s 8ms/step - loss: 0.3511 - val_loss: 0.5680
# Epoch 9/10
# 5625/5625 [==============================] - 84s 15ms/step - loss: 0.3360 - val_loss: 0.5772
# Epoch 10/10
# 5625/5625 [==============================] - 95s 17ms/step - loss: 0.3232 - val_loss: 0.5843
#                       review_id                 user_id  \
# 2000000  NxIV6YoOfsiBSxrNF5i1Dw  r5YAim_lxd4Js2gQVGeLsw
# 2000001  S4ULMYax-92NERQvAivrfw  QJIbIcjPb6qhRnb1d4sTjg
# 2000002  uClUShLNMwHJNLgS9J5poQ  IiVjDaSDELbxLIWu0_Ucrw
# 2000003  3DrBtGCx4N3aXrbpDAxExg  K2vRxDY1uuxtm_YEEfQ9wQ
# 2000004  uNXSrvw9jO4jarViJcfmvg  ctgPXpW4NitQisBWHaS1YA
# ...                         ...                     ...
# 2999995  gZlc76DGyo3IK4tznEdO9A  yy0MrguMeuPuojEZdlEVHA
# 2999996  Ju60Eqh9BwzkokqW3orChg  mjxWgGxFIIy13Vo02_HksQ
# 2999997  b6NXauz7dbzWXf6Y8zNbVA  WWfAP9hq9ldiUOm5ijQliw
# 2999998  E8G36-PTiuH4U4j8yKSNQw  eLkEcFGpwqMaL6Cq5axmcA
# 2999999  yAUrbmFOYwg9CgeKUPvSZA  Sejmtp5di6lxUcEWJV8TnQ
#
#                     business_id  stars  useful  funny  cool  \
# 2000000  T3Bbtht3jO2izyO6f6W8bg      5       3      0     4
# 2000001  EY5cTfLf9BNG3tgoez9fKg      5       0      0     0
# 2000002  6nCLoE5WfY69AywtTmg2Lg      5       2      0     0
# 2000003  wMQMMxaGq0HPG0mApezXMw      5       1      0     0
# 2000004  5uhG34VRsD0A6lOY8F41Dg      5       0      0     1
# ...                         ...    ...     ...    ...   ...
# 2999995  2TW0TCqrRxyolGb3S_uTiA      3       0      0     0
# 2999996  gEmVqHPesM4z0dC3nOnkUw      4       3      8     1
# 2999997  HotEtVKhb7SVb7AFgp4O1g      5       0      0     0
# 2999998  6NFKMheqAVk9Sa2hqssAMw      5       1      0     0
# 2999999  Ydu9tZPmGV31A2wgsLhyPA      5       0      0     0
#
#                                                       text                date
# 2000000  Pros: Makaylah: our bartender and server, she ... 2020-10-31 00:18:49
# 2000001  Authentic and Perfect! \nAs someone who's as b... 2021-02-09 03:12:34
# 2000002  Great fresh food for lunch, I had the appetize... 2020-10-30 00:04:00
# 2000003  I heard good things about Ahi when I moved to ... 2020-05-03 01:21:43
# 2000004  The Habit is yummy. Had a charburger with chee... 2021-02-09 05:32:37
# ...                                                    ...                 ...
# 2999995  This place is quite meh. It's nothing phenomen... 2016-08-18 23:24:18
# 2999996  Nah for real... I'm bouta put y'all on some re... 2016-04-06 20:16:10
# 2999997  The chicken curry here is the best I've had in... 2013-09-17 15:57:33
# 2999998  It is really hard to compete with Red Robin bu... 2018-06-30 02:21:51
# 2999999  Loved this place!! The masala dosas are out of... 2016-09-11 16:20:41
#
# [1000000 rows x 9 columns]
# Epoch 1/10
# 5625/5625 [==============================] - 29s 5ms/step - loss: 0.7525 - val_loss: 0.5665
# Epoch 2/10
# 5625/5625 [==============================] - 28s 5ms/step - loss: 0.5176 - val_loss: 0.5421
# Epoch 3/10
# 5625/5625 [==============================] - 29s 5ms/step - loss: 0.4725 - val_loss: 0.5429
# Epoch 4/10
# 5625/5625 [==============================] - 26s 5ms/step - loss: 0.4397 - val_loss: 0.5479
# Epoch 5/10
# 5625/5625 [==============================] - 27s 5ms/step - loss: 0.4120 - val_loss: 0.5531
# Epoch 6/10
# 5625/5625 [==============================] - 28s 5ms/step - loss: 0.3898 - val_loss: 0.5631
# Epoch 7/10
# 5625/5625 [==============================] - 28s 5ms/step - loss: 0.3704 - val_loss: 0.5731
# Epoch 8/10
# 5625/5625 [==============================] - 28s 5ms/step - loss: 0.3539 - val_loss: 0.5859
# Epoch 9/10
# 5625/5625 [==============================] - 28s 5ms/step - loss: 0.3393 - val_loss: 0.5946
# Epoch 10/10
# 5625/5625 [==============================] - 28s 5ms/step - loss: 0.3259 - val_loss: 0.6011
#                       review_id                 user_id  \
# 3000000  HcA750mPTtKUYuWfHR7vAA  3vofzamIMkrS0PPf5aSmRQ
# 3000001  4C_k3xCaSdFXcotVICxYLg  tCRK0DNqtudWuLEq3IInhA
# 3000002  LInUEmtPAqlcqlk8DfrD9Q  60RKNAZwY5EUooJf624aKw
# 3000003  Dkl-JP_lPuDdE1ka8KMBFA  3jG-b8U7bnE1FPiCl_CE-Q
# 3000004  JgZFJVhMiOxcSWK2QAub6g  qwy5ZpzXgWCB2TMDmCpKLQ
# ...                         ...                     ...
# 3999995  5v7TX6iWkQE-pZxdq9AGsg  IML25ULTDCnR_o58BIQWuA
# 3999996  WuJKJp0VocGryMzFmWFZdg  W83aZrDrYKwycCHB_eOYYg
# 3999997  lZ1Fu3ZMeObL_flSpD7dEg  sZNhZKXbt1zGOP4kg-vGfA
# 3999998  tQp4Y4dJMosEi3D6uOoCFw  jE_kjPwK2UbrQc4P7kgpGg
# 3999999  7acX38OdeuhMtwupF3H49w  Qux_wztMIMRcaxaZt6VNtg
#
#                     business_id  stars  useful  funny  cool  \
# 3000000  7_1GqlDlbkShY0az7J0XNg      4       0      0     0
# 3000001  Sd8NrlgB6SY6GEtIjPupfA      4       0      0     0
# 3000002  ikONTzFKwachQtFtoMGeIQ      4       3      0     5
# 3000003  XXFW9msW3P-p6t6vV0cpeg      1       1      1     1
# 3000004  B2Rk_FNhgFF-XOwesQw7FA      1       0      0     0
# ...                         ...    ...     ...    ...   ...
# 3999995  YVvm1Q3ir5TET0f66FOX_g      5       4      1     3
# 3999996  mFd-j_KM90IOamGmoN5AQA      4       2      1     2
# 3999997  Up1oOg7UxxH6kb_YgkSrAw      5       0      0     0
# 3999998  ffgRv8hnLdAZ_OTkfHcIaA      1       0      0     0
# 3999999  zT98ZdtdWf0TTZMkKtHSeg      1       1      0     0
#
#                                                       text                date
# 3000000  So this place has the best OUTDOOR SEATING in ... 2011-08-15 08:16:03
# 3000001  Great food and prices. I recommend the gyro. P... 2014-10-18 22:46:47
# 3000002  Excellent pizza, salad and service! I came for... 2018-01-18 04:07:13
# 3000003  This place is just terrible!!!  We read the re... 2014-02-16 03:56:18
# 3000004  I took my family of four to dinner and the foo... 2014-08-31 15:52:03
# ...                                                    ...                 ...
# 3999995  Hot Damn! Authentic and fresh, these dishes we... 2014-06-25 02:15:59
# 3999996  Love, love, love \n\nTaco trio OMG. The roaste... 2018-11-06 16:13:38
# 3999997  These guys are amazing. Passion project, hand ... 2019-08-15 12:40:34
# 3999998  I couldn't get a cone for less than $7.09 for ... 2019-12-22 14:17:03
# 3999999  This location regularly overbooks appointments... 2018-08-15 18:35:16
#
# [1000000 rows x 9 columns]
# Epoch 1/10
# 5625/5625 [==============================] - 28s 5ms/step - loss: 0.7535 - val_loss: 0.5646
# Epoch 2/10
# 5625/5625 [==============================] - 26s 5ms/step - loss: 0.5124 - val_loss: 0.5434
# Epoch 3/10
# 5625/5625 [==============================] - 26s 5ms/step - loss: 0.4686 - val_loss: 0.5366
# Epoch 4/10
# 5625/5625 [==============================] - 28s 5ms/step - loss: 0.4357 - val_loss: 0.5388
# Epoch 5/10
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.4101 - val_loss: 0.5480
# Epoch 6/10
# 5625/5625 [==============================] - 25s 4ms/step - loss: 0.3875 - val_loss: 0.5540
# Epoch 7/10
# 5625/5625 [==============================] - 36s 6ms/step - loss: 0.3680 - val_loss: 0.5630
# Epoch 8/10
# 5625/5625 [==============================] - 50s 9ms/step - loss: 0.3516 - val_loss: 0.5760
# Epoch 9/10
# 5625/5625 [==============================] - 55s 10ms/step - loss: 0.3371 - val_loss: 0.5816
# Epoch 10/10
# 5625/5625 [==============================] - 55s 10ms/step - loss: 0.3236 - val_loss: 0.5894
#                       review_id                 user_id  \
# 4000000  tNx450494cTULI7CmykEyA  iOrUgvydcxIDlW78bchkRA
# 4000001  LLus2Mkw4C3PgdPIbm2WoQ  9g2yOSgIpHq3gcpX756HeQ
# 4000002  LQelK02_SN2nkvuhbLRpkg  BsMKUneO8WI0NIuXTnLVaQ
# 4000003  lajxWuowVIOSTRYeSoeFdQ  u5UOl-Jsq1ozwWX84m_kBQ
# 4000004  W-1q9mQNlfXTDtd9DPoqgA  Xv6bH6p63DUheLu5b5ngfg
# ...                         ...                     ...
# 4999995  ylWAkYNyMUE89wZi3mfF_w  SCqdOpu99eB8si3O4VNGZw
# 4999996  RFKsfcOutfhFM9V_K8FUUw  T9nDMe9mljDsAV7MvxcvOw
# 4999997  uuf4-lsOdDNGaxGX7kdKvQ  jh7CWRWIHNPR_n9GQn6Qww
# 4999998  lHXmsAIvC8hfA0fl3qKlOQ  NIhcRW6DWvk1JQhDhXwgOQ
# 4999999  VOTAzkPCl69iZCKg7VPQog  ePR435P_LXoEglMnvx5Wtw
#
#                     business_id  stars  useful  funny  cool  \
# 4000000  LU7WfvB9o5_JSW5IMvGedg      5       0      0     0
# 4000001  6_T2xzR74JqGCTPefAD8Tw      3       1      0     0
# 4000002  h7TO_IsmLCYmKKDVOOIeFw      5       0      0     0
# 4000003  ZfAILO2iad90fCDtratcKg      4       0      0     0
# 4000004  BZnIJonWPti26onuyWQOPw      1       1      2     1
# ...                         ...    ...     ...    ...   ...
# 4999995  RFsp1nH2fHVyAdTSMDWuNg      3       1      1     1
# 4999996  XC30E7D4gfIrLmh4d4prSw      4       0      0     0
# 4999997  SGi8AJhR8iS-LsQwcMOAVA      5       0      0     1
# 4999998  IWHdx0NhDKADkGOgXgOFKQ      5       9      4     5
# 4999999  4uDKV1p3sFt66gGNjx18YQ      4       0      0     0
#
#                                                       text                date
# 4000000  I never knew what "Peak" roasted coffee was un... 2019-01-29 04:08:38
# 4000001  The wagyu did its best to rescue Morimoto from... 2017-11-28 05:42:40
# 4000002  Favorite sushi place. So many options, fresh f... 2019-09-28 05:23:20
# 4000003  The price was right. Wish they had jasmine tea... 2019-09-27 17:43:13
# 4000004  Rude rude rude people. Came by when they were ... 2017-02-28 19:28:59
# ...                                                    ...                 ...
# 4999995  I haven't eaten a lot of Thai food in Reno, ma... 2009-10-26 12:14:40
# 4999996  Good food with generous portions. I had the ch... 2018-09-07 23:06:07
# 4999997  Beer.  Lots and lots of beer.\nIf you can't fi... 2013-03-27 16:27:03
# 4999998  I love a great sandwich and DiNic's shaved por... 2014-08-17 01:32:46
# 4999999  Pretty yummy for your typical take out Chinese... 2016-02-02 21:56:53
#
# [1000000 rows x 9 columns]
# Epoch 1/10
# 5625/5625 [==============================] - 56s 10ms/step - loss: 0.7337 - val_loss: 0.5526
# Epoch 2/10
# 5625/5625 [==============================] - 55s 10ms/step - loss: 0.5078 - val_loss: 0.5311
# Epoch 3/10
# 5625/5625 [==============================] - 55s 10ms/step - loss: 0.4638 - val_loss: 0.5284
# Epoch 4/10
# 5625/5625 [==============================] - 55s 10ms/step - loss: 0.4308 - val_loss: 0.5318
# Epoch 5/10
# 5625/5625 [==============================] - 55s 10ms/step - loss: 0.4041 - val_loss: 0.5379
# Epoch 6/10
# 5625/5625 [==============================] - 55s 10ms/step - loss: 0.3812 - val_loss: 0.5637
# Epoch 7/10
# 5625/5625 [==============================] - 55s 10ms/step - loss: 0.3622 - val_loss: 0.5570
# Epoch 8/10
# 5625/5625 [==============================] - 55s 10ms/step - loss: 0.3447 - val_loss: 0.5624
# Epoch 9/10
# 5625/5625 [==============================] - 55s 10ms/step - loss: 0.3302 - val_loss: 0.5733
# Epoch 10/10
# 5625/5625 [==============================] - 55s 10ms/step - loss: 0.3178 - val_loss: 0.5910
#                       review_id                 user_id  \
# 5000000  ioNJc8Jbc91LNeXYU1cxWg  UlYXVV0Ls5UwJzUqt_m7mQ
# 5000001  LO5p8flmEWqUUQNFnmgFBA  PhJQ6n59_QWZGVfAkryQ1Q
# 5000002  q6hqznQCLqnQuFYZudkwuw  EMJV9rib660I4RpMsbzWbg
# 5000003  5PRQGXbPV5uojvKT5G6vZA  Zs8Zk3sgh5JxRmoZW4PJcg
# 5000004  sF6oKpIrT43owFOZUfTpSw  4-M38FPX7WsfQmmbXYD8BQ
# ...                         ...                     ...
# 5999995  qmS62hb8F_Bn_g1dONUbfw  tuoDDqTDCB-lDgelvMrp5Q
# 5999996  x2_tn_RME9Mg-KkZOM59Gw  427qVnuuXqu7yAAznS3tBA
# 5999997  P9qHgjRLh44QRMaVgs8pDw  eYd1sygl0Thd2JRQTVgX5A
# 5999998  hkMLluL1NKKeujJM3XeNuA  kFpXqhC8gEspuUxJ4O7uqA
# 5999999  xk0qraFoLlZrN-qsaVM37g  sVer7l3TKwICjZ6liQD53Q
#
#                     business_id  stars  useful  funny  cool  \
# 5000000  YJDk7V279i7ZftgJmsj-AQ      5       0      0     0
# 5000001  oOLxSrq4qYkZXPq18Es32g      1       0      0     0
# 5000002  pqwx5KCx2pZBo7QHqRLhdA      3       2      0     1
# 5000003  qsm7SkX60JsajT7Yz248FA      4       0      0     0
# 5000004  D2igy5Aexgdk8d-DV2K1vw      4       0      0     0
# ...                         ...    ...     ...    ...   ...
# 5999995  SvDyTNMMznMKt_W1IQ1v6Q      4       1      0     0
# 5999996  5ELNy7sHTCldOo5QdipBzA      5       0      0     0
# 5999997  r-qXw4hn_eRTUq4BL2DwvQ      5      28     15    31
# 5999998  YSRM9nWQn40eg49tSiI-_Q      3       2      2     0
# 5999999  8qhSEJ27l14Uv3Bger4eVQ      4       3      1     3
#
#                                                       text                date
# 5000000  As an update, my husband and I have now been p... 2014-05-13 12:26:30
# 5000001  I've given up trying to like this place. If yo... 2016-10-06 00:37:46
# 5000002  I've had the unfortunate luck of having to vis... 2011-10-08 03:35:56
# 5000003  Cafe Soho is the highlight to the Sunday footb... 2013-11-22 20:42:45
# 5000004  I don't do Hookah much or hardly at all but th... 2016-02-15 19:36:50
# ...                                                    ...                 ...
# 5999995  This alehouse by the stadium is a great place ... 2018-03-18 11:43:55
# 5999996  We came by because my mom's computer wasn't st... 2018-12-09 20:09:30
# 5999997  Lettuce rejoice for this is the best $2 you mi... 2018-10-12 23:58:07
# 5999998  The Mi Nidito restaurant is in my opinion over... 2018-06-29 20:00:12
# 5999999  I went for brunch on Sunday. Overall, I was pl... 2016-08-09 10:01:48
#
# [1000000 rows x 9 columns]
# Epoch 1/10
# 5625/5625 [==============================] - 55s 10ms/step - loss: 0.7307 - val_loss: 0.5451
# Epoch 2/10
# 5625/5625 [==============================] - 54s 10ms/step - loss: 0.5091 - val_loss: 0.5276
# Epoch 3/10
# 5625/5625 [==============================] - 54s 10ms/step - loss: 0.4655 - val_loss: 0.5284
# Epoch 4/10
# 5625/5625 [==============================] - 54s 10ms/step - loss: 0.4332 - val_loss: 0.5319
# Epoch 5/10
# 5625/5625 [==============================] - 54s 10ms/step - loss: 0.4061 - val_loss: 0.5376
# Epoch 6/10
# 5625/5625 [==============================] - 54s 10ms/step - loss: 0.3840 - val_loss: 0.5465
# Epoch 7/10
# 5625/5625 [==============================] - 54s 10ms/step - loss: 0.3646 - val_loss: 0.5555
# Epoch 8/10
# 5625/5625 [==============================] - 54s 10ms/step - loss: 0.3482 - val_loss: 0.5647
# Epoch 9/10
# 5625/5625 [==============================] - 54s 10ms/step - loss: 0.3336 - val_loss: 0.5786
# Epoch 10/10
# 5625/5625 [==============================] - 54s 10ms/step - loss: 0.3210 - val_loss: 0.5861
#                       review_id                 user_id  \
# 6000000  LEt_rcvZ9UsAhQCRGRBkVQ  rWQaJXlszSGjbpeOhc6MpA
# 6000001  nfHyQfb1oTTvGevA0JrqNg  M0N8g7gkV4bkjUDRsyZKTA
# 6000002  K4gdzC3ut1SJAkHWR_YGQQ  7YtZgk47gwcUZZSc68_41A
# 6000003  7hGVG9nUzhpiiSAniPDTbg  iExzs4voEa1-N0bSYODg1A
# 6000004  1z_2diaMLhSkc0z4L0BxnQ  6AI8lK1tnlOjoWF0qpLyog
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars  useful  funny  cool  \
# 6000000  dAZASdppYH5DQvXLlzGiow      4       1      1     0
# 6000001  PhO1GC_o2DbOIlbODRiu1w      4       0      0     0
# 6000002  QA8QLpwf_YT9C2ST5YJ0vw      1       0      0     0
# 6000003  zropQGh2fc7PMpzd32vneQ      3       2      0     2
# 6000004  ramBBnf8_ZAZ16aUnSUMJg      2       3      0     0
# ...                         ...    ...     ...    ...   ...
# 6990275  jals67o91gcrD4DC81Vk6w      5       1      2     1
# 6990276  2vLksaMmSEcGbjI5gywpZA      5       2      1     2
# 6990277  R1khUUxidqfaJmcpmGd4aw      4       1      0     0
# 6990278  Rr9kKArrMhSLVE9a53q-aA      5       1      0     0
# 6990279  VAeEXLbEcI9Emt9KGYq9aA      3      10      3     7
#
#                                                       text                date
# 6000000  Very good food here!  Casual dining in the Don... 2017-05-12 23:58:29
# 6000001  I've been here twice and was generally pleased... 2019-02-18 21:34:37
# 6000002  The bar 33 is nice but restaurant overrated, h... 2016-05-15 05:00:45
# 6000003  The place is located inside the new China Town... 2017-04-06 23:17:53
# 6000004  Ordered Chicken Fried Rice. Rice was not fried... 2018-11-27 02:18:43
# ...                                                    ...                 ...
# 6990275  Latest addition to services from ICCU is Apple... 2014-12-17 21:45:20
# 6990276  This spot offers a great, affordable east week... 2021-03-31 16:55:10
# 6990277  This Home Depot won me over when I needed to g... 2019-12-30 03:56:30
# 6990278  For when I'm feeling like ignoring my calorie-... 2022-01-19 18:59:27
# 6990279  Located in the 'Walking District' in Nashville... 2018-01-02 22:50:47
#
# [990280 rows x 9 columns]
# Epoch 1/10
# 5571/5571 [==============================] - 57s 10ms/step - loss: 0.7628 - val_loss: 0.5675
# Epoch 2/10
# 5571/5571 [==============================] - 55s 10ms/step - loss: 0.5175 - val_loss: 0.5430
# Epoch 3/10
# 5571/5571 [==============================] - 55s 10ms/step - loss: 0.4725 - val_loss: 0.5411
# Epoch 4/10
# 5571/5571 [==============================] - 55s 10ms/step - loss: 0.4387 - val_loss: 0.5430
# Epoch 5/10
# 5571/5571 [==============================] - 55s 10ms/step - loss: 0.4112 - val_loss: 0.5515
# Epoch 6/10
# 5571/5571 [==============================] - 55s 10ms/step - loss: 0.3887 - val_loss: 0.5583
# Epoch 7/10
# 5571/5571 [==============================] - 55s 10ms/step - loss: 0.3686 - val_loss: 0.5692
# Epoch 8/10
# 5571/5571 [==============================] - 55s 10ms/step - loss: 0.3519 - val_loss: 0.5792
# Epoch 9/10
# 5571/5571 [==============================] - 55s 10ms/step - loss: 0.3368 - val_loss: 0.5871
# Epoch 10/10
# 5571/5571 [==============================] - 55s 10ms/step - loss: 0.3241 - val_loss: 0.6019

# %%
# Save the entire model to an HDF5 file
model.save('final_cnn_model.h5')
